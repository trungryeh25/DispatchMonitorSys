# %%
# 1. Cài đặt YOLOv5
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17496, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 17496 (delta 2), reused 0 (delta 0), pack-reused 17491 (from 3)
# Receiving objects: 100% (17496/17496), 16.59 MiB | 11.14 MiB/s, done.
# Resolving deltas: 100% (11993/11993), done.
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# 2. Upload dataset hoặc mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/TestExam-preInterview/dataset.yaml --weights yolov5s.pt --project /content/drive/MyDrive/TestExam-preInterview/DispatchMonitor/runs
# Out:
# Streaming output truncated to the last 5000 lines.
#       13/49      4.43G    0.02376     0.0136   0.002918         48        640:   5% 3/65 [00:00<00:13,  4.53it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/49      4.43G    0.02417    0.01276   0.002652         46        640:   6% 4/65 [00:00<00:13,  4.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       13/49      4.43G    0.02357    0.01231   0.002884         45        640:   8% 5/65 [00:01<00:23,  2.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python detect.py \
  --weights /content/drive/MyDrive/TestExam-preInterview/DispatchMonitor/yolov5/runs/exp/weights/best.pt \
  --img 640 \
  --conf 0.25 \
  --source /content/drive/MyDrive/TestExam-preInterview/test_images/test1.jpg \
  --save-txt \
  --save-conf
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['/content/drive/MyDrive/TestExam-preInterview/DispatchMonitor/runs/exp/weights/best.pt'], source=/content/drive/MyDrive/TestExam-preInterview/test_images/test1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_format=0, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-421-g79c4c31d Python-3.11.13 torch-2.6.0+cu124 CPU
#
# ...
